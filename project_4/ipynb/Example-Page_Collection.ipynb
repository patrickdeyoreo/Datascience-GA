# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
resp = requests.get('https://en.wikipedia.org/wiki/String_theory')

# %%
string_theory = resp.text

# %%
soup = BeautifulSoup(string_theory, 'html.parser')

# %%
print(soup.get_text())
# Out:
# String theory - Wikipedia
# document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
# ...
